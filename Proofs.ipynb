# %%
import pandas as pd
import numpy as np

# %%
# !dir
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: A00C-CEA9
#
#  Directorio de C:\Users\Santiago\Desktop\Cursos\Udemy_Nanodegree_DataScience\Project-1\AirBNB
#
# 26/03/2021  07:36 a. m.    <DIR>          .
# 26/03/2021  07:36 a. m.    <DIR>          ..
# 25/03/2021  02:12 p. m.                 0 .gitignore
# 26/03/2021  07:23 a. m.    <DIR>          .ipynb_checkpoints
# 25/03/2021  02:18 p. m.    <DIR>          in
# 26/03/2021  07:36 a. m.            23,192 Proofs.ipynb
# 25/03/2021  02:08 p. m.                37 README.md
#                3 archivos         23,229 bytes
#                4 dirs  80,214,417,408 bytes libres

# %%
# !dir  C:\Users\Santiago\Desktop\Cursos\Udemy_Nanodegree_DataScience\Project-1\AirBNB\in
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: A00C-CEA9
#
#  Directorio de C:\Users\Santiago\Desktop\Cursos\Udemy_Nanodegree_DataScience\Project-1\AirBNB\in
#
# 26/03/2021  07:49 a. m.    <DIR>          .
# 26/03/2021  07:49 a. m.    <DIR>          ..
# 17/11/2019  09:30 p. m.        33,521,941 calendar_boston.csv
# 20/09/2019  01:24 a. m.        36,650,955 calendar_seattle.csv
# 17/11/2019  09:31 p. m.        14,756,898 listings_boston.csv
# 20/09/2019  01:24 a. m.        16,871,061 listings_seattle.csv
# 17/11/2019  09:31 p. m.        27,319,622 reviews_boston.csv
# 20/09/2019  01:24 a. m.        36,592,035 reviews_seattle.csv
#                6 archivos    165,712,512 bytes
#                2 dirs  80,200,663,040 bytes libres

# %%
calendar_boston = pd.read_csv(".\in\calendar_boston.csv")
calendar_seattle = pd.read_csv(".\in\calendar_seattle.csv")
listings_boston = pd.read_csv(".\in\listings_boston.csv")
listings_seattle = pd.read_csv(".\in\listings_seattle.csv")
reviews_boston = pd.read_csv('./in/reviews_boston.csv')
reviews_seattle = pd.read_csv("./in/reviews_seattle.csv")

# %%
calendar_boston.head()
calendar_seattle.head()
listings_boston.head()
listings_seattle.head()
reviews_boston.head()
reviews_seattle.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
df_calendar_boston = calendar_boston.copy(deep = True)
df_calendar_seattle = calendar_seattle.copy(deep = True)
df_listings_boston = listings_boston.copy(deep = True)
df_listings_seattle = listings_seattle.copy(deep = True)
df_reviews_boston = reviews_boston.copy(deep = True)
df_reviews_seattle = reviews_seattle.copy(deep = True)

# %%
df_calendar_boston.info()
df_calendar_seattle.info()
df_listings_boston.info()
df_listings_seattle.info()
df_reviews_boston.info()
df_reviews_seattle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308890 entries, 0 to 1308889
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1308890 non-null  int64
#  1   date        1308890 non-null  object
#  2   available   1308890 non-null  object
#  3   price       643037 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 39.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  object
#  2   available   1393570 non-null  object
#  3   price       934542 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 42.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 95 columns):
# ...

# %%
print(df_calendar_boston.shape)
print(df_calendar_seattle.shape)
print(df_listings_boston.shape)
print(df_listings_seattle.shape)
print(df_reviews_boston.shape)
print(df_reviews_seattle.shape)
# Out:
# (1308890, 4)
# (1393570, 4)
# (3585, 95)
# (3818, 92)
# (68275, 6)
# (84849, 6)

# %%
df_calendar_boston.nunique()
# df_calendar_seattle.nunique()
# df_listings_boston.nunique()
# df_listings_seattle.nunique()
# df_reviews_boston.nunique()
# df_reviews_seattle.nunique()
# Out:
# listing_id    3585
# date           365
# available        2
# price         1246
# dtype: int64

# %%
df_calendar_boston['available'].plot(kind="bar")
